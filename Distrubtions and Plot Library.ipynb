# %% [markdown]
# # Distrubtions and Plot Library
# This Module is used for making plots and testing the given column for various type of distributions like normal , welisberg , Exponential , Logistic etc . Find outliers in one column based on Z test

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import distribution as db
a = pd.read_csv('sample data.csv')
a.head()
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income     ...       \
# 0           2/24/11         Employed      F   56274     ...
# 1           1/31/11       Unemployed      F       0     ...
# 2           2/19/11         Employed      F   48767     ...
# ...

# %% [markdown]
# ### hisplot1(dataset,name):
# It is used to plot a histagram for a given dataset[name]

# %%
db.hisplot1(a,'Income')

# %% [markdown]
# ### lineplot(dataset,name)
# Used to do autoscaling and plot line for group of data "
# Input: Name can be a list of features also
# Output:Line plot

# %%
db.lineplot(a,'Months Since Policy Inception')

# %% [markdown]
# ### threed(dataset,name):
# to draw a 3d plot
# Input:Dataset : DataFrame and name is a list of 3 variables
# Output : 3d plot

# %%
db.threed(a,['Customer Lifetime Value','Income','Number of Open Complaints'])

# %% [markdown]
# ### outliers1(dataset,name):
# It is used to find the outliers in a numeric data series or a column in a dataframe based on Z test . It displays their Z score . It returns 1 if its an outlier and 0 if its not .
# Reference : https://onlinecourses.science.psu.edu/stat200/node/135

# %%
db.outliers1(a,'Income') ## print the out
# Out:
# 0.612827437139
# -1.23961684189
# 0.365709777071
# -1.23961684189
# 0.203389651616
# 0.831009913618
# 0.582410930159
# -1.23961684189
# -0.776390558088
# -0.291174851495
# -1.23961684189
# -1.23961684189
# 1.29594794889
# 2.04711058178
# 1.51528256579
# -0.429859639275
# -0.415046405356
# -0.289759364698
# 0.444088243652
# 0.93759936124
# 0.661381926096
# -0.785706436308
# -0.776390558088
# -1.23961684189
# -0.651366863811
# 1.97126682411
# -1.23961684189
# -0.893612615834
# 1.61058103733
# 1.2519691033
# -0.477294906114
# 0.932957881279
# -1.23961684189
# 0.5544303772
# -0.0130810733878
# 1.0313177545
# 0.152991737994
# 0.923312820083
# -1.23961684189
# 0.51305207712
# -1.23961684189
# 0.408635237139
# 0.736172298238
# 0.183902019438
# 1.81632039732
# -0.906977444659
# -1.23961684189
# -0.475319808258
# -1.23961684189
# -1.23961684189
# -0.423111388267
# -0.147058544611
# -0.0540972721948
# -0.25753235135
# -0.689848353703
# 0.295132947022
# 0.891810009281
# -1.23961684189
# ...

# %% [markdown]
# ### typedis(dataset,name,dis):
# Type any type of ditribution . Dis is used to take in the type of code distribution visit refer http://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html#module-scipy.stats for more reference and throws KS Test Statistic either D,D+,D-  test and p value as a result . we are taking p value as 0.05 to check a hypothesis with 95 % confidence
# Output :
# Zscore , Pvalue

# %%
db.typedis(a,'Income','norm')
# Out:
# It is Not as norm  distribution
# (0.74633238449748196, 0.0)

# %% [markdown]
# ### norm(dataset,name):
# Perform KS test for normal distribution .throws KS Test Statistic either D,D+,D-  test and p value as a result . we are taking p value as 0.05 to check a hypothesis with 95 % confidence
# Output :
# Zscore , Pvalue

# %%
db.norm(a,'Income')
# Out:
# It is Not a normal distribution
# (0.74633238449748196, 0.0)

# %% [markdown]
# ### welisberg(dataset,name):
# Perform KS test for welisberg distribution .throws KS Test Statistic either D,D+,D-  test and p value as a result . we are taking p value as 0.05 to check a hypothesis with 95 % confidence
# Output :
# Zscore , Pvalue

# %%
db.welisberg(a,'Income')

# %% [markdown]
# ### exponential(dataset,name):
# Perform KS test for exponential distribution .throws KS Test Statistic either D,D+,D-  test and p value as a result . we are taking p value as 0.05 to check a hypothesis with 95 % confidence
# Output :
# Zscore , Pvalue

# %%
db.exponential(a,'Income')
# Out:
# It is Not a Exponential distribution
# (0.74633238449748196, 0.0)

# %% [markdown]
# ### logistic(dataset,name)
# Perform KS test for logistic distribution .throws KS Test Statistic either D,D+,D-  test and p value as a result . we are taking p value as 0.05 to check a hypothesis with 95 % confidence
# Output :
# Zscore , Pvalue

# %%
db.logistic(a,'Income')
# Out:
# It is Not a Exponential distribution
# (0.74633238449748196, 0.0)

# %% [markdown]
# ### distri(dataset,name):
# It is used to tell whether name of dataset is continous or a discrete distribution

# %%
for i in a:
    print i,'is ', db.distri(a,i)
# Out:
# Customer is  discrete
# State is  discrete
# Customer Lifetime Value is  discrete
# Response is  discrete
# Coverage is  discrete
# Education is  discrete
# Effective To Date is  discrete
# EmploymentStatus is  discrete
# Gender is  discrete
# Income is  discrete
# Location Code is  discrete
# Marital Status is  discrete
# Monthly Premium Auto is  discrete
# Months Since Last Claim is  discrete
# Months Since Policy Inception is  discrete
# Number of Open Complaints is  discrete
# Number of Policies is  discrete
# Policy Type is  discrete
# Policy is  discrete
# Renew Offer Type is  discrete
# Sales Channel is  discrete
# Total Claim Amount is  discrete
# Vehicle Class is  discrete
# Vehicle Size is  discrete
