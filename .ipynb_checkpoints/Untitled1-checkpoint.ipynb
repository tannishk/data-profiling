# %%
import pandas as pd 
from replace import replace
a = pd.read_csv('user accounts.csv',delimiter=';')


print a    
a = replace(a,'available_balance',False,0)
##timeoutlier(a,'available_balance')
print a
# Out:
#       id  customer_id account_type account_number  available_balance  \
# 0      1           19      savings       xxxx6302           21481.44
# 1      2           22      savings       xxxx4287            4923.48
# 2      3          251     checking       xxxx-X48                NaN
# 3      4          251      unknown       xxxx-X44                NaN
# 4      5          251     checking       xxxx-X49                NaN
# 5      6          251     checking       xxxx-X47                NaN
# 6      7          251      savings       xxxx-X48                NaN
# 7      8          251      savings       xxxx-X02                NaN
# 8      9          251      savings       xxxx-X44                NaN
# 9     10          583      savings       xxxx-X44          159674.54
# 10    11          583      savings       xxxx-X06           44176.48
# 11    12          979      savings       xxxx3916            1380.86
# 12    13         1066      savings       xxxx3243           15183.66
# ...
