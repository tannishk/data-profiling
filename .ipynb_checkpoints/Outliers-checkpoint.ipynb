# %% [markdown]
# # Outlier Module
# This module contains functions to find outliers in a multivariate envirnment and to transform text data series to numeric one , To find outliers in a time series

# %%
import pandas as pd
import muloutlier as ml 
a = pd.read_csv('sample data.csv')
a.head()
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income     ...       \
# 0           2/24/11         Employed      F   56274     ...
# 1           1/31/11       Unemployed      F       0     ...
# 2           2/19/11         Employed      F   48767     ...
# ...

# %% [markdown]
# ### transform(dataset,col)
# This function is used to map all text data series dataset[col] to numeric data . It can be passed any data series if numeric it won't be altered .
# Output: An altered data frame

# %%
for i in a:
    a = ml.transform(a,i)
a.head()
# Out:
#    Customer  State  Customer Lifetime Value  Response  Coverage  Education  \
# 0         0      0              2763.519279         0         0          0
# 1         1      1              6979.535903         0         1          0
# 2         2      2             12887.431650         0         2          0
# 3         3      3              7645.861827         0         0          0
# 4         4      0              2813.692575         0         0          0
#
#    Effective To Date  EmploymentStatus  Gender  Income      ...       \
# 0                  0                 0       0   56274      ...
# 1                  1                 1       0       0      ...
# 2                  2                 0       0   48767      ...
# 3                  3                 1       1       0      ...
# 4                  4                 0       1   43836      ...
#
#    Months Since Policy Inception  Number of Open Complaints  \
# 0                              5                          0
# ...

# %% [markdown]
# ### mutout(df)
# Here df is the data frame . It considers all the columns of a data frame in both numeric and text form . It performs automatic transformation and preprocessing as well. It then uses the concept of oneSVM using rbf kernal evaluate the records which can be outliers .
# Output: All the record numbers which are outliers and throws back a list which contains -1  to that a given value is an outlier and +1 to indicate that its not an outlier

# %%
ml.mulout(a)
# Out:
# [-1.  1.  1. ...,  1.  1.  1.]
# 1 is an outlier
# 7 is an outlier
# 9 is an outlier
# 28 is an outlier
# 32 is an outlier
# 45 is an outlier
# 46 is an outlier
# 52 is an outlier
# 53 is an outlier
# 75 is an outlier
# 80 is an outlier
# 87 is an outlier
# 93 is an outlier
# 110 is an outlier
# 117 is an outlier
# 137 is an outlier
# 150 is an outlier
# 152 is an outlier
# 159 is an outlier
# 161 is an outlier
# 172 is an outlier
# 192 is an outlier
# 197 is an outlier
# 198 is an outlier
# 212 is an outlier
# 214 is an outlier
# 217 is an outlier
# 218 is an outlier
# 230 is an outlier
# 238 is an outlier
# 244 is an outlier
# 245 is an outlier
# 249 is an outlier
# 251 is an outlier
# 256 is an outlier
# 260 is an outlier
# 276 is an outlier
# 293 is an outlier
# 295 is an outlier
# 298 is an outlier
# 300 is an outlier
# 303 is an outlier
# 317 is an outlier
# 322 is an outlier
# 348 is an outlier
# 352 is an outlier
# 355 is an outlier
# 365 is an outlier
# 370 is an outlier
# ...

# %% [markdown]
# ## Outliers for a time series

# %%
b = pd.read_csv('time series sample.csv')
b.head()
# Out:
#                   Date      Open      High       Low  Close
# 8-July-2015   28031.45  28031.45  27635.72  27687.72    NaN
# 9-July-2015   27681.49  27798.13  27540.60  27573.66    NaN
# 10-July-2015  27705.36  27729.46  27530.90  27661.40    NaN
# 13-July-2015  27739.32  28005.17  27635.06  27961.19    NaN
# 14-July-2015  27986.92  28018.59  27853.96  27932.90    NaN

# %% [markdown]
# ### timeoutlier(dataset, col, window):
# It is used to find outliers for time series .Here window is the window size for which an outlier should be calculated . It also draws a plot showing the the ranges and data points for a time series
# Output :
# list with a value of True if an outlier and false if not an outlier

# %%
ml.timeoutlier(b,'High',3)
# Out:
# muloutlier.py:14: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=3,center=False).mean()
#   x = pd.rolling_mean(dataset[col], window)
# muloutlier.py:15: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=3,center=False).std()
#   y = pd.rolling_std(dataset[col], window)
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...
