# %% [markdown]
# # Similarity Module
#
# Similarity module is used to test similarity between 2 datasets . It is used to tell the similarity between 2 columns based on cosine , euclids and mahanabis distance and to convert them into vectors based on term frequency and other

# %%
import pandas as pd
import similarity as sm
a = pd.read_csv('sample data.csv')
a.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income     ...       \
# 0           2/24/11         Employed      F   56274     ...
# 1           1/31/11       Unemployed      F       0     ...
# 2           2/19/11         Employed      F   48767     ...
# 3           1/20/11       Unemployed      M       0     ...
# 4            2/3/11         Employed      M   43836     ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %% [markdown]
# ### createdict(a,b)
# It is used to convert a , b to numeric vectors based on indivual items of the both the vectors . a and b should be passed in list form as demonstrated .
# Output: It returns 2 vectors based on their frequency

# %%
x,y = sm.createdict(a['Coverage'].tolist(),a['Education'].tolist())
sm.createdict(a['Coverage'].tolist(),a['Education'].tolist())
# Out:
# ([2742, 824, 0, 0, 0, 0, 5568, 0], [0, 0, 342, 2622, 2748, 2681, 0, 741])

# %% [markdown]
# ### converttfidf(x,dictte)
# It is a support function for createdict to create vector

# %% [markdown]
# ### euclids(x,y)
# It is used to calcualte euclids distance between two input vectors x,y
# Output: Euclids Distance

# %%
sm.euclids(x,y)
# Out:
# 7840.941142490486

# %% [markdown]
# ### manhattan(x,y)
# It is used to calcualte manhattan distance between two input vectors x,y
# Output: Manhattan Distance

# %%
sm.manhattan(x,y)
# Out:
# 18268

# %% [markdown]
# ###  cosine(x,y):
# It is used to determine cosine similairty between two vectors x,y . 0 is that they are not at all similar . 1 they are a perfect match
# Output:Cosine Similarity

# %%
sm.cosine(x,y)
# Out:
# 0.0

# %% [markdown]
# ### MahalanobisDist(x, y):
# It is used to calculate Mahalanobis Distance

# %%
sm.MahalanobisDist(x, y)
# Out:
# [0.94692759056953146,
#  1.1809828534884388,
#  1.2627299333796049,
#  1.141675750741171,
#  1.2450923337537001,
#  1.1897793934638909,
#  2.2253572985907089,
#  0.94480273201697185]

# %% [markdown]
# ### compare(a,b):
# "Find Cosine similarity between 2 columns of a and b dataframe  Code any be altered to include other similarity "
# Output: Value of similairity between columns of a and b given a and b is of same data type
# If value > 0.7 then there is a chance of match . If value = 0 No chance of match and if value = 1 perfect match

# %%
sm.compare(a,a)
# Out:
# 1st column is  Customer 2nd column is  Customer  similarity is  1.0
# 1st column is  Customer 2nd column is  State  similarity is  0.0
# 1st column is  Customer 2nd column is  Response  similarity is  0.0
# 1st column is  Customer 2nd column is  Coverage  similarity is  0.0
# 1st column is  Customer 2nd column is  Education  similarity is  0.0
# 1st column is  Customer 2nd column is  Effective To Date  similarity is  0.0
# 1st column is  Customer 2nd column is  EmploymentStatus  similarity is  0.0
# 1st column is  Customer 2nd column is  Gender  similarity is  0.0
# 1st column is  Customer 2nd column is  Location Code  similarity is  0.0
# 1st column is  Customer 2nd column is  Marital Status  similarity is  0.0
# 1st column is  Customer 2nd column is  Policy Type  similarity is  0.0
# 1st column is  Customer 2nd column is  Policy  similarity is  0.0
# 1st column is  Customer 2nd column is  Renew Offer Type  similarity is  0.0
# ...
